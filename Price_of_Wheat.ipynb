# %% [markdown]
# # Price of Wheat

# %% [markdown]
# Here we will clean the dataset containing the price of wheat.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# We will start by storing the dataset into a dataframe. We got the dataset from http://www.indexmundi.com/commodities/?commodity=wheat&months=300.

# %%
price_df=pd.read_csv("data/price_of_wheat.csv")

# %%
price_df.head()
# Out:
#   Wheat - Monthly Price Unnamed: 1 Unnamed: 2
# 0                 Month      Price     Change
# 1                Nov-90      112.8          -
# 2                Dec-90     113.17      0.33%
# 3                Jan-91     111.33     -1.63%
# 4                Feb-91     113.91      2.32%

# %% [markdown]
# Let's clean up the dataframe and create a new column for year and month.

# %%
# change column names
price_df.columns = ['month-year', 'price', 'change']
# remove first row
price_df = price_df[~price_df['month-year'].isin(['Month'])]
# add columns for month and year
month = []
year = []
for row in price_df['month-year']:
    time = row.split('-')
    month.append(time[0])
    if time[1][0] == '9':
        year.append('19'+time[1])
    else:
        year.append('19'+time[1])
price_df['month'] = month
price_df['year'] = year
# remove month-year column
price_df.drop('month-year', axis=1)
# Out:
#       price   change month  year
# 1     112.8        -   Nov  1990
# 2    113.17    0.33%   Dec  1990
# 3    111.33   -1.63%   Jan  1991
# 4    113.91    2.32%   Feb  1991
# 5    119.42    4.84%   Mar  1991
# 6    120.89    1.23%   Apr  1991
# 7    122.04    0.95%   May  1991
# 8    120.15   -1.55%   Jun  1991
# 9    118.21   -1.61%   Jul  1991
# 10   125.33    6.02%   Aug  1991
# 11   135.37    8.01%   Sep  1991
# 12   146.89    8.51%   Oct  1991
# 13   149.54    1.80%   Nov  1991
# 14   160.84    7.56%   Dec  1991
# 15   169.95    5.66%   Jan  1992
# 16   177.13    4.22%   Feb  1992
# 17   169.35   -4.39%   Mar  1992
# 18   159.93   -5.56%   Apr  1992
# 19   149.69   -6.40%   May  1992
# 20   148.67   -0.68%   Jun  1992
# 21   136.32   -8.31%   Jul  1992
# 22   128.17   -5.98%   Aug  1992
# 23   138.74    8.25%   Sep  1992
# 24   140.58    1.33%   Oct  1992
# 25   147.57    4.97%   Nov  1992
# 26   147.83    0.18%   Dec  1992
# 27   155.65    5.29%   Jan  1993
# 28   148.88   -4.35%   Feb  1993
# 29    147.9   -0.66%   Mar  1993
# 30   141.99   -4.00%   Apr  1993
# ..      ...      ...   ...   ...
# 271  319.11    3.36%   May  1913
# 272  313.52   -1.75%   Jun  1913
# 273  304.68   -2.82%   Jul  1913
# 274  305.49    0.27%   Aug  1913
# 275  307.51    0.66%   Sep  1913
# 276  325.07    5.71%   Oct  1913
# 277  306.75   -5.64%   Nov  1913
# 278  291.56   -4.95%   Dec  1913
# 279  228.21  -21.73%   Jan  1914
# 280  242.76    6.38%   Feb  1914
# 281  275.57   13.52%   Mar  1914
# 282  273.47   -0.76%   Apr  1914
# 283  287.85    5.26%   May  1914
# 284  261.59   -9.12%   Jun  1914
# 285  238.53   -8.82%   Jul  1914
# 286   229.1   -3.95%   Aug  1914
# 287  211.16   -7.83%   Sep  1914
# 288  212.78    0.77%   Oct  1914
# 289  215.95    1.49%   Nov  1914
# 290  232.97    7.88%   Dec  1914
# 291  210.61   -9.60%   Jan  1915
# 292  201.71   -4.23%   Feb  1915
# 293  202.68    0.48%   Mar  1915
# 294   195.9   -3.35%   Apr  1915
# 295  193.15   -1.40%   May  1915
# 296  199.82    3.45%   Jun  1915
# 297   199.2   -0.31%   Jul  1915
# 298  173.47  -12.92%   Aug  1915
# 299  163.83   -5.56%   Sep  1915
# 300  165.39    0.95%   Oct  1915
#
# [300 rows x 4 columns]
