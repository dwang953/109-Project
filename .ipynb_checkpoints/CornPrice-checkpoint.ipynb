# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# Store corn commodity price data set into data frame. Data obtained from: http://www.indexmundi.com/commodities/?commodity=corn&months=300

# %%
cornprice_df=pd.read_csv("data/cornPrice_perMonth_1990_2015.csv")

# %%
cornprice_df.head()
# Out:
#   Maize (corn) - Monthly Price Unnamed: 1 Unnamed: 2
# 0                        Month      Price     Change
# 1                       Nov-90        100          -
# 2                       Dec-90     102.36      2.36%
# 3                       Jan-91     105.51      3.08%
# 4                       Feb-91     106.29      0.74%

# %%
# rename column names for easy calling (retrieval)
cornprice_df.columns = ['month-year', 'price', 'change']
cornprice_df = cornprice_df[~cornprice_df['month-year'].isin(['Month'])]
cornprice_df.head()

# Split the Month and the Year
month = []
year = []
for row in cornprice_df['month-year']:
    suffix_year = row.split('-')
    month.append(suffix_year[0])
    if suffix_year[1][0] == '9':
        year.append('19'+suffix_year[1])
    else:
        year.append('19'+suffix_year[1])
cornprice_df['Month'] = month
cornprice_df['Year'] = year

# remove month-year column 
cornprice_df.drop('month-year', axis=1)
# Out:
#       price   change Month  Year
# 1       100        -   Nov  1990
# 2    102.36    2.36%   Dec  1990
# 3    105.51    3.08%   Jan  1991
# 4    106.29    0.74%   Feb  1991
# 5    109.05    2.60%   Mar  1991
# 6    110.23    1.08%   Apr  1991
# 7    105.74   -4.07%   May  1991
# 8    105.11   -0.60%   Jun  1991
# 9    105.73    0.59%   Jul  1991
# 10   110.12    4.15%   Aug  1991
# 11   108.85   -1.15%   Sep  1991
# 12   109.52    0.62%   Oct  1991
# 13    106.8   -2.48%   Nov  1991
# 14   106.72   -0.07%   Dec  1991
# 15   109.59    2.69%   Jan  1992
# 16   113.92    3.95%   Feb  1992
# 17   116.68    2.42%   Mar  1992
# 18   109.06   -6.53%   Apr  1992
# 19   109.18    0.11%   May  1992
# 20    110.2    0.93%   Jun  1992
# 21   102.39   -7.09%   Jul  1992
# 22    97.54   -4.74%   Aug  1992
# 23    98.22    0.70%   Sep  1992
# 24    94.56   -3.73%   Oct  1992
# 25    95.17    0.65%   Nov  1992
# 26    94.04   -1.19%   Dec  1992
# 27     94.1    0.06%   Jan  1993
# 28    94.25    0.16%   Feb  1993
# 29    97.54    3.49%   Mar  1993
# 30   100.49    3.02%   Apr  1993
# ..      ...      ...   ...   ...
# 271  295.29    5.36%   May  1913
# 272  297.06    0.60%   Jun  1913
# 273  278.93   -6.10%   Jul  1913
# 274  234.89  -15.79%   Aug  1913
# 275  207.41  -11.70%   Sep  1913
# 276  201.73   -2.74%   Oct  1913
# 277  199.14   -1.28%   Nov  1913
# 278   197.5   -0.82%   Dec  1913
# 279  198.72    0.62%   Jan  1914
# 280  209.32    5.33%   Feb  1914
# 281  222.33    6.22%   Mar  1914
# 282  222.36    0.01%   Apr  1914
# 283  216.92   -2.45%   May  1914
# 284  202.56   -6.62%   Jun  1914
# 285  182.23  -10.04%   Jul  1914
# 286  176.43   -3.18%   Aug  1914
# 287  163.06   -7.58%   Sep  1914
# 288  163.31    0.15%   Oct  1914
# 289  178.67    9.41%   Nov  1914
# 290  178.67    0.00%   Dec  1914
# 291  174.71   -2.22%   Jan  1915
# 292   173.7   -0.58%   Feb  1915
# 293  174.23    0.31%   Mar  1915
# 294  172.05   -1.25%   Apr  1915
# 295   166.3   -3.34%   May  1915
# 296  166.72    0.25%   Jun  1915
# 297   179.6    7.73%   Jul  1915
# 298  162.74   -9.39%   Aug  1915
# 299  166.01    2.01%   Sep  1915
# 300  171.39    3.24%   Oct  1915
#
# [300 rows x 4 columns]
